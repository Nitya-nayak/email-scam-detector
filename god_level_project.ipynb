# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd

df = pd.read_csv("/content/drive/MyDrive/NEW_PROJECT/combined_data.csv")

print("Shape of Dataset: ",df.shape)
print("Null values: \n",df.isnull().sum())
print(df.isnull().any())
df.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Shape of Dataset:  (83448, 2)
# Null values:
#  label    0
# text     0
# dtype: int64
# label    False
# text     False
# dtype: bool
#    label                                               text
# 0      1  ounce feather bowl hummingbird opec moment ala...
# 1      1  wulvob get your medircations online qnb ikud v...
# 2      0   computer connection from cnn com wednesday es...
# 3      1  university degree obtain a prosperous future m...
# 4      0  thanks for all your answers guys i know i shou...

# %%
#Distribution of labels (spam or not)

Distribution_label = df['label'].value_counts(normalize = True)*100
print("Percentage of Distributed label: \n",Distribution_label)
# Out:
# Percentage of Distributed label:
#  label
# 1    52.619595
# 0    47.380405
# Name: proportion, dtype: float64

# %%
import re

def feature_extraction(txt):
  feature = {}
  feature['URL_Extraction'] = len(re.findall(r'https\S+|www\S+',txt))
  feature['NUM_Extraction'] = len(re.findall(r'\d+',txt))
  feature['Char_len_ex'] = len(txt)
  feature['Special_Char'] = len(re.findall(r'[^a-zA-Z0-9\s]',txt))
  return feature

feature_new = df['text'].apply(feature_extraction).apply(pd.Series)

df = pd.concat([df,feature_new],axis=1)

# %%
df['URL_Extraction'].sum()
df['NUM_Extraction'].sum()
df['Char_len_ex'].sum()
df['Special_Char'].sum()
# Out:
# np.int64(2991005)

# %%
df['word_count'] = df['text'].astype(str).apply(lambda x : len(x.split()))
df.groupby('label')['word_count'].describe()
# Out:
#          count        mean         std  min    25%    50%    75%       max
# label
# 0      39538.0  365.057944  984.324750  1.0  106.0  200.0  378.0  101984.0
# 1      43910.0  208.754634  338.269557  1.0   61.0  122.0  249.0   25393.0

# %%
df['text'] = df['text'].astype(str)
df['text'] = df['text'].apply(lambda x : x.lower())
df.head()
# Out:
#    label                                               text  URL_Extraction  \
# 0      1  ounce feather bowl hummingbird opec moment ala...               0
# 1      1  wulvob get your medircations online qnb ikud v...               0
# 2      0   computer connection from cnn com wednesday es...               0
# 3      1  university degree obtain a prosperous future m...               0
# 4      0  thanks for all your answers guys i know i shou...               0
#
#    NUM_Extraction  Char_len_ex  Special_Char  word_count
# 0               0          148             0          20
# 1               0          808             1         103
# 2               0         2235             1         337
# 3               0          592             1          76
# 4               0         1362            32         222

# %%
import re
def handle_msg(txt):
  text = txt.lower()
  text = re.sub(r'http\S+|www\S+','URL',text)
  text = re.sub(r'\d+','NUM',text)
  text = re.sub(r'[^a-z0-9\s/\:]',' ',text)
  text = re.sub(r'\s+',' ',text).strip()

  return text

df['text'] = df['text'].apply(handle_msg)

# %%
import nltk
from nltk.corpus import stopwords
nltk.download("stopwords")
stop_words = set(stopwords.words('english'))


def remove_st(txt):
  text = txt.split()
  return ' '.join(word for word in text if word not in stop_words)

df['text'] = df['text'].apply(remove_st)

df['text'].head()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 0    ounce feather bowl hummingbird opec moment ala...
# 1    wulvob get medircations online qnb ikud viagra...
# 2    computer connection cnn com wednesday escapenu...
# 3    university degree obtain prosperous future mon...
# 4    thanks answers guys know checked rsync manual ...
# Name: text, dtype: object

# %%
df.describe()
# Out:
#               label  URL_Extraction  NUM_Extraction    Char_len_ex  \
# count  83448.000000    83448.000000    83448.000000   83448.000000
# mean       0.526196        0.003607        5.354005    1662.952725
# std        0.499316        0.185580       29.231291    4178.578068
# min        0.000000        0.000000        0.000000       1.000000
# 25%        0.000000        0.000000        0.000000     449.000000
# 50%        1.000000        0.000000        0.000000     879.000000
# 75%        1.000000        0.000000        2.000000    1861.000000
# max        1.000000       23.000000     2950.000000  598705.000000
#
#        Special_Char     word_count
# count  83448.000000   83448.000000
# mean      35.842740     282.811775
# std      214.308859     724.818152
# min        0.000000       1.000000
# 25%        1.000000      80.000000
# 50%        5.000000     152.000000
# 75%       22.000000     312.000000
# max    12741.000000  101984.000000

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tf_idf = TfidfVectorizer(
    max_features = 5000,
    min_df = 2,
    stop_words = 'english'
)

x_idf = tf_idf.fit_transform(df['text'])

# %%
from scipy.sparse import hstack

features = df[['URL_Extraction','NUM_Extraction','Char_len_ex','Special_Char','word_count']]

X = hstack([features.values,x_idf])
Y = df['label']

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(X,Y, test_size = 0.2, random_state = 42,stratify = Y)

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(
    max_iter = 1000,
    solver = 'liblinear',
    class_weight = 'balanced'
)

model.fit(x_train,y_train)

y_pred = model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix

print("Accuracy : ",accuracy_score(y_test,y_pred))
print("Classification report: \n",classification_report(y_test,y_pred))
print("Confusion Matrix: ",confusion_matrix(y_test,y_pred))
# Out:
# Accuracy :  0.9756740563211503
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.98      0.97      0.97      7908
#            1       0.97      0.98      0.98      8782
#
#     accuracy                           0.98     16690
#    macro avg       0.98      0.98      0.98     16690
# weighted avg       0.98      0.98      0.98     16690
#
# Confusion Matrix:  [[7666  242]
#  [ 164 8618]]

# %%
def use_apply(txt):
  fet

user_input = input("Enter your email / Message: ")
user.apply(user_input)
